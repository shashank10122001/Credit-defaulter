# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

        
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn import metrics
from xgboost import XGBRegressor
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score, GridSearchCV

# %%
filename = "/kaggle/input/cassandra-udyam21/user_data_training.csv"
df = pd.read_csv(filename)

# %%
filename1 = "/kaggle/input/cassandra-udyam21/user_data_testing.csv"
df1 = pd.read_csv(filename1)

# %%
filename2 = "/kaggle/input/cassandra-udyam21/payment_history_data.csv"
dfu = pd.read_csv(filename2)
dfy=dfu

# %%
idr = dfu["id"].values
print(idr)

# %%
import pandas_profiling
df.profile_report()

# %%
import pandas_profiling
dfy.profile_report()

# %%
sc_X = StandardScaler()
rb_X = RobustScaler()
dfu =dfu.drop(["recent_payment_activity"],axis= 1)
dfu["id2"]= idr

dfu['max_bal'] = dfu['max_bal'].fillna(dfu['max_bal'].mean())
dfu["amount"] = rb_X.fit_transform(dfu["curr_remaining"].values.reshape(-1,1))
dfu['curr_remaining'] = dfu['curr_remaining'].fillna(dfu['curr_remaining'].mean())

# %%
dfu.info()

# %%
for i in range(len(dfu["last_update"])):
    if(type(dfu["last_update"][i])!=float):
        dfu["last_update"][i] = int(dfu["last_update"][i][0:2]) + 30*(int(dfu["last_update"][i][3:5]) + 12*(int(dfu["last_update"][i][6:10] )-1900))
#         print(dfu["recent_payment_activity"][i])
print(dfu["last_update"])

# %%
dfu['last_update'] = dfu['last_update'].fillna(dfu['last_update'].mean())
dfu['p_limit'] = dfu['p_limit'].fillna(0)
dfu.sort_values(by=['id'], inplace=True)
dfu = dfu.groupby(["id"], sort=False).mean()
dfu.info()
x = dfu.to_numpy()

# %%
a = dfu["id2"]
a = a.to_numpy()
print(a)

# %%
print(x.shape)

# %%
df1['Beta'] = df1['Beta'].fillna(df1['Beta'].mean())
df1.info()

# %%
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler
view_df = shuffle(df, random_state=2)

# %%
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler
view_df1 = shuffle(df1, random_state=2)

# %%
df.info()

# %%
df1.info()

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn import metrics
from keras.utils import to_categorical

# %%
X = df.drop(['label'], axis = 1)
y = df['label']
df2 = df

# %%
x_t = X.to_numpy()

# %%
print(x_t.shape)

# %%
Xt = df1

# %%
Xt1 = Xt.to_numpy()

# %%
print(Xt1)

# %%
count =  0
print(x_t.shape)
# tdata = pd.DataFrame()
# a = np.random.rand(N,N)
b = np.zeros((715,24))
b[:,:-11] = x_t
c = b
            
# print(tdata)
print(b.shape)
print(x.shape)
# print(b)

# %%
d = np.zeros((410,24))
d[:,:-11] = Xt1
d.shape

# %%
print(x)

# %%
constantt = 13
count =0
for i in range((c.shape)[0]):
#     counter1 = 0;
    indexo = c[i][0]
    for j in range((x.shape)[0]):
        counter2 = 0
        counter3 = 0
        if(indexo == x[j][10] ):
            for k in range(11):
                c[i][constantt+counter2] = x[j][counter3]
                counter2=counter2+1
                counter3=counter3+1
                if(counter2 == 10):
                    counter3 = counter3 +1
#     counter1 = counter1+1
            
print(c)

# %%
constantt = 13
count =0
for i in range((d.shape)[0]):
#     counter1 = 0;
    indexo = d[i][0]
    for j in range((x.shape)[0]):
        counter2 = 0
        counter3 = 0
        if(indexo == x[j][10] ):
            for k in range(11):
                d[i][constantt+counter2] = x[j][counter3]
                counter2=counter2+1
                counter3=counter3+1
                if(counter2 == 10):
                    counter3 = counter3 +1
#     counter1 = counter1+1
            
print(d)

# %%
print(d.shape)

# %%
print(c.shape)

# %%
tdf=pd.DataFrame(data=c[0:,0:],index=[i for i in range(c.shape[0])],columns=['f'+str(i) for i in range(c.shape[1])])

# %%
tdf1=pd.DataFrame(data=d[0:,0:],index=[i for i in range(d.shape[0])],columns=['f'+str(i) for i in range(d.shape[1])])

# %%
tdf1.info()

# %%
tdf['f2'] = tdf['f2'].fillna(tdf['f2'].mean())
tdf.head()

# %%
tdf.info()

# %%
print(x.shape)

# %%
Xt['Beta'] = Xt['Beta'].fillna(Xt['Beta'].mean())
Xt.info()

# %%
from imblearn.over_sampling import RandomOverSampler
oversample = RandomOverSampler(sampling_strategy=0.5)
X_over, y_over = oversample.fit_resample(tdf, y)

# %%
from imblearn.under_sampling import TomekLinks

# %%
undersample = TomekLinks()
X_over, y_over = undersample.fit_resample(X_over, y_over)

# %%
print(X_over.shape,y_over.shape)

# %%
print(y_over)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_over, y_over)

# %%
X_train.info()

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn import metrics
from numpy import mean
from numpy import std
from sklearn.ensemble import AdaBoostClassifier
import lightgbm as lgb
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold

# %%
print( Xt,X_train.shape)

# %%
rfc = RandomForestClassifier(class_weight = 'balanced')
params = {'n_estimators' : [80, 90, 100, 110, 120],
          'max_depth' : [3, 4, 5, 6, 7]
          }
clf = RandomizedSearchCV(rfc, params, scoring = 'f1')

print('Training model using Cross validation.....')
search = clf.fit(X_train, y_train)

print('The Best score was found to be {:.3f}'.format(search.best_score_))
print('The Best params were {}'.format(search.best_params_))

# %%
xgb = GradientBoostingClassifier()
params = {'n_estimators': [80, 90, 100, 110, 120],
          'max_depth': [3, 4, 5, 6, 7, 8 ]
          }


clf = RandomizedSearchCV(xgb, params, scoring = 'f1')
print('Training model using Cross validation.....')
search = clf.fit(X_train, y_train)

print('The Best score was found to be {:.3f}'.format(search.best_score_))
print('The Best params were {}'.format(search.best_params_))

# %%
grid_search = {'n_estimators': [80, 90, 100, 110, 120],
          'max_depth': [3, 4, 5, 6, 7]
}
model = GradientBoostingClassifier()
clf = GridSearchCV(estimator= model,param_grid = grid_search,scoring= 'f1',verbose= 4,n_jobs= -1)
clf.fit(X_train,y_train)

# %%
y_predict= clf.best_estimator_.predict(tdf1)

# %%
model = XGBClassifier()
cv = RepeatedStratifiedKFold(n_splits=7, n_repeats=3, random_state=2)
n_scores = cross_val_score(model, X_train, y_train, scoring='f1', cv=cv, n_jobs=-1)

# %%
print('Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))

# %%
model.fit(X_train, y_train)
y_predict= model.predict(tdf1)

# %%
y_predict= clf.predict(tdf1)

# %%
print(y_predict)
y_ans = y_predict

# %%
y_predict = model.predict(tdf1)

# %%
print(len(y_ans))

# %%
df2.info()

# %%
df_ans = pd.DataFrame(y_ans)

df_ans.value_counts()

# %%
dfp = df1["id"]
df_ans = df_ans.join(dfp)


df_ans.value_counts()

# %%
df_ans.to_csv("predictions1.csv", index = False)

# %%
import pandas_profiling
dfy.profile_report()
